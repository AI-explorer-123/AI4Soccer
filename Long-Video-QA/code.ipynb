# %% [markdown]
# ## 收集SN-caption-test-align对应的比赛信息

# %%
import os
import shutil


def copy_original_files(data_dir, original_dir):
    """
    遍历 Data 文件夹下的比赛文件夹，复制 original 文件夹下对应的所有文件。

    Args:
        data_dir (str): Data 文件夹的路径。
        original_dir (str): original 文件夹的路径。
    """

    for season_dir in os.listdir(data_dir):
        data_season_path = os.path.join(data_dir, season_dir)
        original_season_path = os.path.join(original_dir, season_dir)

        # 检查 Data 文件夹下的赛季文件夹是否存在
        if os.path.isdir(data_season_path):
            # 检查 original 文件夹下的赛季文件夹是否存在
            if os.path.isdir(original_season_path):
                for match_dir in os.listdir(data_season_path):
                    data_match_path = os.path.join(data_season_path, match_dir)
                    original_match_path = os.path.join(original_season_path, match_dir)

                    # 检查 Data 文件夹下的比赛文件夹是否存在
                    if os.path.isdir(data_match_path):
                        # 检查 original 文件夹下的比赛文件夹是否存在
                        if os.path.isdir(original_match_path):
                            # 复制 original 文件夹下的所有文件到 Data 文件夹下的对应比赛文件夹
                            for filename in os.listdir(original_match_path):
                                file_path = os.path.join(
                                    original_match_path, filename)
                                if os.path.isfile(file_path):
                                    shutil.copy2(file_path, data_match_path)
                                    print(
                                        f"已复制 {season_dir}/{match_dir}/{filename} 到 {data_match_path}")
                        else:
                            print(
                                f"警告：original 文件夹下不存在 {season_dir}/{match_dir} 文件夹")
            else:
                print(f"警告：original 文件夹下不存在 {season_dir} 文件夹")

# %%
# 替换为您的 Data 和 original 文件夹路径
data_directory = "./Data"
original_directory = "../SoccerNet/ASR"

# 调用函数执行复制操作
copy_original_files(data_directory, original_directory)

# %%
# 替换为您的 Data 和 original 文件夹路径
data_directory = "./Data"
original_directory = "../SoccerNet/dataset-v2label"

# 调用函数执行复制操作
copy_original_files(data_directory, original_directory)

# %%
# 替换为您的 Data 和 original 文件夹路径
data_directory = "./Data"
original_directory = "../SoccerNet/Raw_match/"

# 调用函数执行复制操作
copy_original_files(data_directory, original_directory)

# %%
# 替换为您的 Data 和 original 文件夹路径
data_directory = "./Data"
original_directory = "../SoccerNet/LLaMA-ASR-Summary/events_json/"

# 调用函数执行复制操作
copy_original_files(data_directory, original_directory)

# %%
# 替换为您的 Data 和 original 文件夹路径
data_directory = "./Data"
original_directory = "../SoccerNet/LLaMA-ASR-Summary/events_json_visual_evidential/"

# 调用函数执行复制操作
copy_original_files(data_directory, original_directory)

# %%
# 替换为您的 Data 和 original 文件夹路径
data_directory = "./Data"
original_directory = "../SoccerNet/MatchTime_withtype/SN-Caption-test-align/"

# 调用函数执行复制操作
copy_original_files(data_directory, original_directory)

# %% [markdown]
# ## 重命名文件夹

# %%
import os


def rename_json_files(folder_path):
    """
    递归地遍历文件夹，并重命名符合条件的 JSON 文件。

    Args:
        folder_path (str): 文件夹的路径。
    """

    for root, _, files in os.walk(folder_path):
        for file in files:
            if file == "sn-caption-test-align.json":
                old_file_path = os.path.join(root, file)
                new_file_path = os.path.join(root, "events_commentaries.json")
                os.rename(old_file_path, new_file_path)
                print(f"已重命名: {old_file_path} -> {new_file_path}")


# 替换为您的文件夹路径
folder_path = "./Data"  # 将 "your_folder_path" 替换为实际的文件夹路径

# 调用函数执行重命名操作
rename_json_files(folder_path)

# %% [markdown]
# ## 测试 Offline Video Model

# %% [markdown]
# ### llava-onevision-qwen2-7b-ov-hf

# %%
import subprocess
import cv2
import torch
from transformers import AutoProcessor, LlavaOnevisionForConditionalGeneration
from PIL import Image

model = LlavaOnevisionForConditionalGeneration.from_pretrained("llava-hf/llava-onevision-qwen2-7b-ov-hf", torch_dtype=torch.float16, device_map="auto")
processor = AutoProcessor.from_pretrained("llava-hf/llava-onevision-qwen2-7b-ov-hf")
processor.tokenizer.padding_side = "left"

video_path = "/DB/data/jiayuanrao-1/sports/haokai_intern/Dataset/Long-Video-QA/Data/spain_laliga_2016-2017/2017-03-12 - 22-45 Real Madrid 2 - 1 Betis/1_224p_clipped.mp4"

# %%
question = "Which part of the body was used to score the goal? \na) Header (Head)\nb) Left foot\nc) Right foot\nd) Other body part"

conversation = [
    {
        "role": "user",
        "content": [
            {"type": "video", "path": video_path},
            {"type": "text", "text": question},
        ],
    },
]

inputs = processor.apply_chat_template(
    conversation,
    num_frames=8,
    add_generation_prompt=True,
    tokenize=True,
    return_dict=True,
    return_tensors="pt"
).to(model.device, torch.float16)
out = model.generate(**inputs, max_new_tokens=60)
processor.batch_decode(out, skip_special_tokens=True,
                       clean_up_tokenization_spaces=True)

# %% [markdown]
# ## 统计数据集事件

# %% [markdown]
# ### SoccerNetV2

# %%
import os
import json


def count_average_events(directory):
    events = {}
    events_counts = 0
    match_count = 0
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.json'):
                match_count += 1
                path = os.path.join(root, file)
                with open(path, 'r') as f:
                    data = json.load(f)
                    annotations = data['annotations']
                    events_counts += len(annotations)
                    for annotation in annotations:
                        label = annotation["label"]
                        if events.get(label) == None:
                            events[label] = 0
                        else:
                            events[label] += 1
    events = {key:value/match_count for key, value in events.items()}
    events_counts /= match_count

    return events, events_counts, match_count

# %%
directory = '../SoccerNet/dataset-v2label'
soccernetv2_events, soccernetv2_events_counts, match_count = count_average_events(directory)
soccernetv2_events, soccernetv2_events_counts, match_count
# Out:
# ({'Kick-off': 5.13,
#   'Shots on target': 11.638,
#   'Offside': 4.194,
#   'Indirect free-kick': 21.04,
#   'Ball out of play': 63.618,
#   'Throw-in': 37.834,
#   'Clearance': 15.79,
#   'Foul': 23.346,
#   'Substitution': 5.676,
#   'Shots off target': 10.51,
#   'Corner': 9.67,
#   'Goal': 3.404,
#   'Direct free-kick': 4.398,
#   'Yellow card': 4.092,
#   'Penalty': 0.344,
#   'Red card': 0.108,
#   'Yellow->red card': 0.09},
#  220.916,
#  500)

# %% [markdown]
# ### SoccerReplay-1988

# %%
import os
import json


def count_soccerreplay_1988_average_events(directory):
    events = {}
    events_count = 0
    match_count = 0
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.json'):
                match_count += 1
                path = os.path.join(root, file)
                with open(path, 'r') as f:
                    data = json.load(f)
                    annotations = data['comments']
                    events_count += len(annotations)
                    for annotation in annotations:
                        label = annotation["comments_type"]
                        if events.get(label) == None:
                            events[label] = 0
                        else:
                            events[label] += 1
    return events, events_count, match_count


directory_path = '../SoccerReplay-1988/SoccerReplay-1988'
soccerreplay_1988_events, soccerreplay_1988_events_count, match_count = count_soccerreplay_1988_average_events(directory_path)
len(soccerreplay_1988_events), {
    key: [value, f'{value/match_count:.2f}'] for key, value in soccerreplay_1988_events.items()}, soccerreplay_1988_events_count/match_count, match_count
# Out:
# (26,
#  {'statistics and summary': [6446, '3.24'],
#   'start of half game': [7250, '3.65'],
#   'foul with no card': [14010, '7.05'],
#   'clearance': [19073, '9.59'],
#   'corner': [20328, '10.23'],
#   'goal': [7274, '3.66'],
#   'off side': [4416, '2.22'],
#   'injury': [3864, '1.94'],
#   'substitution': [14441, '7.26'],
#   'free kick': [2026, '1.02'],
#   'saved by goal-keeper': [5975, '3.01'],
#   'yellow card': [8025, '4.04'],
#   'lead to corner': [7889, '3.97'],
#   'show added time': [3547, '1.78'],
#   'shot off target': [11024, '5.55'],
#   'end of half game': [4030, '2.03'],
#   '': [176, '0.09'],
#   'foul lead to penalty': [1008, '0.51'],
#   'penalty': [470, '0.24'],
#   'ball possession': [4543, '2.29'],
#   'ball out of play': [1665, '0.84'],
#   'throw in': [310, '0.16'],
#   'second yellow card': [163, '0.08'],
#   'red card': [390, '0.20'],
#   'var': [1500, '0.75'],
#   'wcl-icon-settings-info-rounded': [98, '0.05']},
#  75.43611670020121,
#  1988)

# %%
import os
import json


def count_goals(directory):
    match = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.json'):
                goals = 0
                path = os.path.join(root, file)
                with open(path, 'r') as f:
                    data = json.load(f)
                    annotations = data['comments']
                    for annotation in annotations:
                        label = annotation["comments_type"]
                        if label == 'goal':
                            goals += 1
                    if goals >= 10:
                        match.append([file, goals])
    return match


directory_path = '../SoccerReplay-1988/SoccerReplay-1988'
matches = count_goals(
    directory_path)
matches
# Out:
# [['2021-04-18_Lazio_5-3_Benevento_nF9kQM9n.json', 10],
#  ['2020-10-05_Aston_Villa_7-2_Liverpool_6J0L2p0r.json', 11],
#  ['2023-09-30_Aston_Villa_6-1_Brighton_E3fbIwnp.json', 10],
#  ['2020-03-01_Lecce_2-7_Atalanta_Uo3vjpqp.json', 10],
#  ['2022-08-27_Liverpool_9-0_Bournemouth_UsamHrKG.json', 11],
#  ['2022-10-02_Manchester_City_6-3_Manchester_Utd_4fpwmb6T.json', 11],
#  ['2019-08-14_FC_Copenhagen_1-2_Crvena_zvezda_YsUm9yEM.json', 15],
#  ['2022-10-03_Girona_3-5_Real_Sociedad_8Gb9KrXQ.json', 10]]

# %% [markdown]
# #### 统计进球事件

# %%
import os
import json
import re


def extract_score_from_filename(filename):
    # 匹配形如 _3-3_ 或 _4-0_ 的比分
    match = re.search(r'_(\d+)-(\d+)_', filename)
    if match:
        return int(match.group(1)) + int(match.group(2))
    return None


def count_goals_and_compare(directory):
    mismatched_matches = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.json'):
                file_path = os.path.join(root, file)

                # 提取文件名中包含的比分进球数总和
                expected_goals = extract_score_from_filename(file)
                if expected_goals is None:
                    continue  # 跳过无法识别比分的文件

                # 统计 comments 中 'goal' 类型的数量
                with open(file_path, 'r', encoding='utf-8') as f:
                    try:
                        data = json.load(f)
                        comments = data.get('comments', [])
                        actual_goals = sum(1 for c in comments if c.get(
                            'comments_type') == 'goal')

                        if expected_goals != actual_goals:
                            mismatched_matches.append({
                                'file': file,
                                'expected_goals': expected_goals,
                                'actual_goals': actual_goals
                            })
                    except Exception as e:
                        print(f"Error processing file {file}: {e}")
    return mismatched_matches


# 修改路径为你的实际路径
directory_path = '../SoccerReplay-1988/SoccerReplay-1988'
result = count_goals_and_compare(directory_path)

# 打印不一致的比赛文件
for match in result:
    print(
        f"{match['file']}: expected {match['expected_goals']}, found {match['actual_goals']}")
# Out:
# 2019-01-20_Fiorentina_3-3_Sampdoria_GdfimYws.json: expected 6, found 7
# 2019-03-04_Napoli_1-2_Juventus_29Qtz4MD.json: expected 3, found 4
# 2019-04-30_Atalanta_2-0_Udinese_6w99xiq5.json: expected 2, found 1
# 2019-03-17_Genoa_2-0_Juventus_ObsVrY4o.json: expected 2, found 3
# 2019-05-27_Atalanta_3-1_Sassuolo_bBW7eQ6s.json: expected 4, found 5
# 2019-05-13_AS_Roma_2-0_Juventus_KM2WUasd.json: expected 2, found 3
# 2022-04-22_Burnley_2-0_Southampton_CzfH0o8b.json: expected 2, found 3
# 2021-08-28_Manchester_City_5-0_Arsenal_jwTbynnG.json: expected 5, found 6
# 2022-03-13_Manchester_Utd_3-2_Tottenham_0dQbr4hU.json: expected 5, found 6
# 2022-05-08_Brighton_4-0_Manchester_Utd_OEiic62a.json: expected 4, found 5
# 2021-11-08_West_Ham_3-2_Liverpool_0S6SM1kD.json: expected 5, found 6
# 2021-10-23_Everton_2-5_Watford_pfkXX6tH.json: expected 7, found 8
# 2022-04-09_Arsenal_1-2_Brighton_MmrxRsM3.json: expected 3, found 4
# 2021-09-19_West_Ham_1-2_Manchester_Utd_vuy4tYTC.json: expected 3, found 4
# 2022-02-20_Manchester_City_2-3_Tottenham_x2LdzUxd.json: expected 5, found 7
# 2021-10-30_Liverpool_2-2_Brighton_0p0bJSrL.json: expected 4, found 5
# 2022-04-23_Arsenal_3-1_Manchester_Utd_2ywewCBQ.json: expected 4, found 5
# 2021-12-03_Manchester_Utd_3-2_Arsenal_MZMKmVgT.json: expected 5, found 6
# 2022-02-16_Manchester_Utd_2-0_Brighton_dluJNyy0.json: expected 2, found 3
# 2021-08-15_Newcastle_2-4_West_Ham_hC0sp36e.json: expected 6, found 7
# 2022-01-22_Brentford_1-2_Wolves_tvIaglrr.json: expected 3, found 4
# 2022-02-10_Tottenham_2-3_Southampton_AVswQnJJ.json: expected 5, found 6
# 2021-11-20_Watford_4-1_Manchester_Utd_zoLAZvZI.json: expected 5, found 6
# 2022-04-10_Manchester_City_2-2_Liverpool_QLQKIJTq.json: expected 4, found 5
# 2021-09-25_Leeds_1-2_West_Ham_zNYQeDTa.json: expected 3, found 4
# 2021-10-24_Manchester_Utd_0-5_Liverpool_ve75FbQk.json: expected 5, found 6
# 2021-04-18_Atalanta_1-0_Juventus_0hrbMv9B.json: expected 1, found 2
# 2021-02-15_Inter_3-1_Lazio_jmG6Lq6R.json: expected 4, found 5
# 2021-04-18_Lazio_5-3_Benevento_nF9kQM9n.json: expected 8, found 10
# 2020-10-04_Benevento_1-0_Bologna_QZXymePL.json: expected 1, found 2
# 2021-04-22_Udinese_0-1_Cagliari_GSvZNipG.json: expected 1, found 2
# 2020-11-01_Spezia_1-4_Juventus_4MdRONyt.json: expected 5, found 6
# 2020-12-06_Juventus_2-1_Torino_vcCHjXQk.json: expected 3, found 4
# 2020-09-28_AS_Roma_2-2_Juventus_d4qZSZXk.json: expected 4, found 5
# 2021-04-25_Fiorentina_1-1_Juventus_fw2KZlqS.json: expected 2, found 3
# 2021-05-15_Genoa_3-4_Atalanta_G2ZH9eQb.json: expected 7, found 8
# 2021-04-27_Lazio_3-0_AC_Milan_0KvmV8iq.json: expected 3, found 5
# 2021-01-04_Juventus_4-1_Udinese_rqxiUbW8.json: expected 5, found 7
# 2020-09-20_Verona_3-0_AS_Roma_htMuKMqK.json: expected 3, found 0
# 2021-04-04_Torino_2-2_Juventus_U9ivEeaf.json: expected 4, found 5
# 2021-05-16_Juventus_3-2_Inter_prRY5DPN.json: expected 5, found 6
# 2020-01-03_Liverpool_2-0_Sheffield_Utd_WdOfjAms.json: expected 2, found 3
# 2019-12-05_Manchester_Utd_2-1_Tottenham_rcXF3QM4.json: expected 3, found 4
# 2019-12-30_Liverpool_1-0_Wolves_G6wyC3XE.json: expected 1, found 3
# 2020-02-01_West_Ham_3-3_Brighton_21CcFxv7.json: expected 6, found 7
# 2019-08-18_Manchester_City_2-2_Tottenham_6qYwmp8a.json: expected 4, found 5
# 2019-11-23_Crystal_Palace_1-2_Liverpool_faaUexPQ.json: expected 3, found 4
# 2019-09-22_Chelsea_1-2_Liverpool_GUPI3B4E.json: expected 3, found 4
# 2020-02-25_Liverpool_3-2_West_Ham_prZ7VlU4.json: expected 5, found 6
# 2020-02-23_Manchester_Utd_3-0_Watford_OYXBU8qB.json: expected 3, found 4
# 2019-11-02_Aston_Villa_1-2_Liverpool_OIHalZa3.json: expected 3, found 4
# 2019-12-02_Leicester_2-1_Everton_YiqTgkgt.json: expected 3, found 4
# 2020-07-03_Manchester_City_4-0_Liverpool_2FgiFWv0.json: expected 4, found 5
# 2019-10-26_Manchester_City_3-0_Aston_Villa_KOZXZZpA.json: expected 3, found 4
# 2019-12-14_Liverpool_2-0_Watford_W0KvTtjG.json: expected 2, found 4
# 2020-01-20_Liverpool_2-0_Manchester_Utd_IZNCFQGh.json: expected 2, found 3
# 2020-01-12_Tottenham_0-1_Liverpool_OW4kbPoI.json: expected 1, found 2
# 2020-01-02_Manchester_City_2-1_Everton_AmNbkU2m.json: expected 3, found 4
# 2019-08-10_West_Ham_0-5_Manchester_City_r9LkLzJk.json: expected 5, found 7
# 2019-11-24_Manchester_City_2-1_Chelsea_vXz1jGnl.json: expected 3, found 4
# 2020-07-02_West_Ham_3-2_Chelsea_h4n4CUOI.json: expected 5, found 6
# 2020-02-23_Leicester_0-1_Manchester_City_S6v3WUEb.json: expected 1, found 2
# 2020-01-02_West_Ham_4-0_Bournemouth_6ZIJp6HI.json: expected 4, found 5
# 2019-11-30_Chelsea_0-1_West_Ham_dSLaBHOD.json: expected 1, found 2
# 2019-11-25_Sheffield_Utd_3-3_Manchester_Utd_86u5kz2f.json: expected 6, found 7
# 2019-08-10_Watford_0-3_Brighton_CtJstxeF.json: expected 3, found 4
# 2020-02-18_Chelsea_0-2_Manchester_Utd_O6chyK0Q.json: expected 2, found 3
# 2019-10-28_Arsenal_2-2_Crystal_Palace_djlwEhOj.json: expected 4, found 5
# 2022-11-02_Plzen_2-4_Barcelona_vBy27zkc.json: expected 6, found 7
# 2022-07-26_AEK_Larnaca_1-2_Midtjylland_MH1ILFjd.json: expected 3, found 9
# 2022-10-13_Bayer_Leverkusen_0-3_FC_Porto_YXjcDNYp.json: expected 3, found 4
# 2022-09-08_Club_Brugge_KV_1-0_Bayer_Leverkusen_Is8Kfc5i.json: expected 1, found 2
# 2022-10-05_Bayern_Munich_5-0_Plzen_4bAWiekA.json: expected 5, found 6
# 2022-09-14_Marseille_0-1_Eintracht_Frankfurt_xMosbWBq.json: expected 1, found 2
# 2022-10-12_D._Zagreb_1-1_Salzburg_fPUFqhEm.json: expected 2, found 3
# 2022-09-07_Dortmund_3-0_FC_Copenhagen_2TOj66RH.json: expected 3, found 4
# 2022-09-08_Ajax_4-0_Rangers_xABGQIjB.json: expected 4, found 5
# 2022-10-06_RB_Leipzig_3-1_Celtic_8SfkbiTt.json: expected 4, found 6
# 2022-10-26_Sevilla_3-0_FC_Copenhagen_GCMv98sa.json: expected 3, found 4
# 2022-08-04_Crvena_zvezda_5-0_Pyunik_Yerevan_WOKegHRd.json: expected 5, found 6
# 2022-10-12_FC_Copenhagen_0-0_Manchester_City_z3EWAUCn.json: expected 0, found 1
# 2023-03-08_Benfica_5-1_Club_Brugge_KV_dQnCcBEU.json: expected 6, found 8
# 2023-02-15_PSG_0-1_Bayern_Munich_4lFRoEFI.json: expected 1, found 2
# 2022-10-06_Sevilla_1-4_Dortmund_YmXZ9lSh.json: expected 5, found 4
# 2022-08-25_PSV_0-1_Rangers_IcdkNyzm.json: expected 1, found 2
# 2022-10-27_Tottenham_1-1_Sporting_CP_KQWiZ4e4.json: expected 2, found 3
# 2023-09-03_Toulouse_2-2_Clermont_Wry5Sp40.json: expected 4, found 5
# 2019-03-11_Valladolid_1-4_Real_Madrid_A5j4QeW4.json: expected 5, found 6
# 2019-04-14_Ath_Bilbao_3-2_Rayo_Vallecano_QcAIdKC0.json: expected 5, found 6
# 2020-01-13_PSG_3-3_Monaco_CjKjptL6.json: expected 6, found 7
# 2019-09-14_Lille_2-1_Angers_AVqongXA.json: expected 3, found 4
# 2019-09-28_Lyon_0-1_Nantes_drCrMaEs.json: expected 1, found 2
# 2020-02-02_PSG_5-0_Montpellier_KxL4AxZB.json: expected 5, found 6
# 2019-09-15_St_Etienne_2-2_Toulouse_WvosmZH4.json: expected 4, found 7
# 2020-02-01_Rennes_3-2_Nantes_SM6eEKZn.json: expected 5, found 6
# 2023-05-27_FC_Koln_1-2_Bayern_Munich_C2M87NL1.json: expected 3, found 4
# 2022-11-05_Hertha_Berlin_2-3_Bayern_Munich_WKMgaMZH.json: expected 5, found 6
# 2022-11-12_B._Monchengladbach_4-2_Dortmund_n9faGEA9.json: expected 6, found 7
# 2022-08-21_Bochum_0-7_Bayern_Munich_hbsUgouk.json: expected 7, found 9
# 2022-08-28_Bayern_Munich_1-1_B._Monchengladbach_vFqtiqP7.json: expected 2, found 3
# 2022-10-30_Union_Berlin_2-1_B._Monchengladbach_tC1ejRjm.json: expected 3, found 5
# 2022-08-06_Eintracht_Frankfurt_1-6_Bayern_Munich_vDAQyDJ3.json: expected 7, found 8
# 2023-01-26_Werder_Bremen_1-2_Union_Berlin_hWzlz91r.json: expected 3, found 4
# 2022-11-13_Schalke_0-2_Bayern_Munich_MRnCDCfS.json: expected 2, found 3
# 2022-08-06_Union_Berlin_3-1_Hertha_Berlin_pADYZjlG.json: expected 4, found 5
# 2022-09-10_Bayern_Munich_2-2_Stuttgart_SfMi5ZqI.json: expected 4, found 5
# 2022-08-14_Bayern_Munich_2-0_Wolfsburg_W6Z3kWm3.json: expected 2, found 3
# 2022-10-01_Bayern_Munich_4-0_Bayer_Leverkusen_fqL7WBrH.json: expected 4, found 5
# 2023-02-12_RB_Leipzig_1-2_Union_Berlin_4dZLjPM2.json: expected 3, found 4
# 2023-03-19_Union_Berlin_2-0_Eintracht_Frankfurt_Gbsl3ETM.json: expected 2, found 3
# 2023-03-05_Stuttgart_1-2_Bayern_Munich_4IS08ll5.json: expected 3, found 4
# 2022-05-13_Rayo_Vallecano_1-5_Villarreal_hzySaO8j.json: expected 6, found 8
# 2022-02-19_Osasuna_0-3_Atl._Madrid_Cnd8nvan.json: expected 3, found 4
# 2022-04-09_Sevilla_4-2_Granada_CF_OIXWS7Kn.json: expected 6, found 7
# 2021-12-21_Levante_3-4_Valencia_8QPeVTAS.json: expected 7, found 8
# 2021-09-23_Real_Madrid_6-1_Mallorca_rFfxMJY7.json: expected 7, found 8
# 2022-05-11_Granada_CF_1-0_Ath_Bilbao_nFkXAlHi.json: expected 1, found 2
# 2021-11-07_Real_Madrid_2-1_Rayo_Vallecano_8ppteyC1.json: expected 3, found 4
# 2023-08-23_Rakow_0-1_FC_Copenhagen_ra4BXy0m.json: expected 1, found 2
# 2023-10-04_FC_Copenhagen_1-2_Bayern_Munich_vwQm7Sw5.json: expected 3, found 4
# 2023-11-08_Atl._Madrid_6-0_Celtic_pf3bIXcs.json: expected 6, found 7
# 2023-09-21_Bayern_Munich_4-3_Manchester_Utd_AcjWuju6.json: expected 7, found 8
# 2023-10-04_PSV_2-2_Sevilla_W6JVHqhN.json: expected 4, found 5
# 2023-11-30_Arsenal_6-0_Lens_4v0MLRhb.json: expected 6, found 7
# 2023-09-20_Barcelona_5-0_Antwerp_G067uJ1M.json: expected 5, found 6
# 2023-10-05_Celtic_1-2_Lazio_EZfFEkc6.json: expected 3, found 4
# 2023-09-21_Real_Sociedad_1-1_Inter_40XVNBKD.json: expected 2, found 5
# 2023-10-04_Union_Berlin_2-3_Braga_Gd6xEzik.json: expected 5, found 6
# 2023-10-05_Antwerp_2-3_Shakhtar_Donetsk_trjnYzfd.json: expected 5, found 6
# 2023-10-05_Newcastle_4-1_PSG_pUJ7qAdt.json: expected 5, found 6
# 2023-04-24_Juventus_0-1_Napoli_UiIhdegU.json: expected 1, found 2
# 2022-10-02_Lazio_4-0_Spezia_8ni6jMSo.json: expected 4, found 5
# 2022-11-07_Juventus_2-0_Inter_bXJZ0k4I.json: expected 2, found 3
# 2022-08-16_Verona_2-5_Napoli_fB9qO0lH.json: expected 7, found 8
# 2022-08-22_Napoli_4-0_Monza_O0fgUyBj.json: expected 4, found 5
# 2023-01-29_Juventus_0-2_Monza_fH6l2g1o.json: expected 2, found 3
# 2023-05-22_Napoli_3-1_Inter_vcfS4MtQ.json: expected 4, found 5
# 2022-09-11_Sampdoria_1-2_AC_Milan_KlifO3qg.json: expected 3, found 5
# 2023-04-30_Inter_3-1_Lazio_U9Zc5YVp.json: expected 4, found 6
# 2022-08-28_Juventus_1-1_AS_Roma_CpFWseuj.json: expected 2, found 3
# 2023-01-29_AC_Milan_2-5_Sassuolo_UZb1aio4.json: expected 7, found 9
# 2022-11-11_Lazio_1-0_Monza_Qodod0Ij.json: expected 1, found 2
# 2023-02-26_Bologna_1-0_Inter_xG8yIdc0.json: expected 1, found 2
# 2022-11-09_Cremonese_0-0_AC_Milan_KpH63rQG.json: expected 0, found 1
# 2022-09-12_Juventus_2-2_Salernitana_8ANy6MTO.json: expected 4, found 6
# 2023-03-20_Lazio_1-0_AS_Roma_pr3Cz29d.json: expected 1, found 2
# 2023-03-13_Juventus_4-2_Sampdoria_0GjLn82i.json: expected 6, found 7
# 2023-04-09_Lazio_2-1_Juventus_6Vfy0Ix8.json: expected 3, found 4
# 2023-05-29_Lazio_3-2_Cremonese_lnYPDaJt.json: expected 5, found 6
# 2023-03-20_Inter_0-1_Juventus_6i48yrfj.json: expected 1, found 2
# 2023-05-22_Napoli_3-1_Inter_vcfS4MtQ.json: expected 4, found 5
# 2022-09-18_Udinese_3-1_Inter_lrKuz1r5.json: expected 4, found 5
# 2022-05-06_Salernitana_2-1_Venezia_A7Z7DfiB.json: expected 3, found 4
# 2022-02-06_Atalanta_1-2_Cagliari_zDior6d2.json: expected 3, found 4
# 2022-01-18_Fiorentina_6-0_Genoa_S4s9tgLc.json: expected 6, found 7
# 2021-09-24_Sampdoria_0-4_Napoli_fBoGwmBg.json: expected 4, found 5
# 2021-08-23_Udinese_2-2_Juventus_YJF484Fi.json: expected 4, found 5
# 2021-12-05_Napoli_2-3_Atalanta_2RabtjQL.json: expected 5, found 6
# 2022-04-28_Atalanta_4-4_Torino_SpyuALpJ.json: expected 8, found 9
# 2022-05-22_Lazio_3-3_Verona_6JIXmKLf.json: expected 6, found 7
# 2021-12-18_Atalanta_1-4_AS_Roma_tfMNp5H7.json: expected 5, found 7
# 2022-04-16_AC_Milan_2-0_Genoa_lQ856AF0.json: expected 2, found 3
# 2021-09-13_AS_Roma_2-1_Sassuolo_2J3xcVC7.json: expected 3, found 4
# 2021-09-22_Fiorentina_1-3_Inter_vwpqoVIJ.json: expected 4, found 5
# 2021-11-01_AS_Roma_1-2_AC_Milan_fLKv7wCl.json: expected 3, found 4
# 2022-05-08_Venezia_4-3_Bologna_pSA7q5U8.json: expected 7, found 8
# 2021-09-26_Juventus_3-2_Sampdoria_xYqqsMHo.json: expected 5, found 6
# 2021-11-07_Venezia_3-2_AS_Roma_pUyZGEuD.json: expected 5, found 6
# 2021-12-01_Salernitana_0-2_Juventus_808NvwkH.json: expected 2, found 3
# 2021-10-25_Inter_1-1_Juventus_ClPXACgt.json: expected 2, found 3
# 2021-10-19_Venezia_1-0_Fiorentina_MJdBgBO5.json: expected 1, found 2
# 2021-10-28_Juventus_1-2_Sassuolo_2icJM9hh.json: expected 3, found 4
# 2020-10-04_Leicester_0-3_West_Ham_ABcxa2a7.json: expected 3, found 4
# 2020-10-05_Aston_Villa_7-2_Liverpool_6J0L2p0r.json: expected 9, found 11
# 2021-02-13_Leicester_3-1_Liverpool_YDUBJOHU.json: expected 4, found 5
# 2021-04-11_Tottenham_1-3_Manchester_Utd_theOXEhn.json: expected 4, found 5
# 2021-04-10_Liverpool_2-1_Aston_Villa_vgCAEihO.json: expected 3, found 4
# 2020-10-18_Newcastle_1-4_Manchester_Utd_MTZMAabJ.json: expected 5, found 6
# 2021-05-01_Crystal_Palace_0-2_Manchester_City_IPnxyu5e.json: expected 2, found 3
# 2021-02-01_West_Ham_1-3_Liverpool_4015Gb5L.json: expected 4, found 5
# 2021-03-20_Fulham_1-2_Leeds_Ot8ljH96.json: expected 3, found 4
# 2020-12-17_Liverpool_2-1_Tottenham_xUHBOtuh.json: expected 3, found 4
# 2020-12-27_Arsenal_3-1_Chelsea_0WU1ZcgA.json: expected 4, found 5
# 2021-04-03_Chelsea_2-5_West_Brom_W6XR3zv6.json: expected 7, found 8
# 2020-09-27_West_Brom_3-3_Chelsea_ELPp9nNE.json: expected 6, found 7
# 2021-02-21_West_Ham_2-1_Tottenham_z555ZXSc.json: expected 3, found 4
# 2020-12-06_West_Ham_1-3_Manchester_Utd_QJcbbpRn.json: expected 4, found 5
# 2021-01-13_Burnley_0-1_Manchester_Utd_ny9dswY4.json: expected 1, found 2
# 2021-01-31_Leicester_1-3_Leeds_xlQAfHr2.json: expected 4, found 5
# 2021-02-03_Wolves_2-1_Arsenal_hQZh7fS7.json: expected 3, found 4
# 2021-04-11_West_Ham_3-2_Leicester_E5gWVhNb.json: expected 5, found 7
# 2021-02-28_Leeds_0-1_Aston_Villa_2VFPU9sT.json: expected 1, found 2
# 2020-11-22_Manchester_Utd_1-0_West_Brom_G80FTYLe.json: expected 1, found 2
# 2021-01-29_Tottenham_1-3_Liverpool_vuPK4169.json: expected 4, found 6
# 2020-09-20_Arsenal_2-1_West_Ham_vVXZfd24.json: expected 3, found 4
# 2020-12-20_Tottenham_0-2_Leicester_44ygyKOc.json: expected 2, found 3
# 2021-03-03_Manchester_City_4-1_Wolves_df6dlevJ.json: expected 5, found 6
# 2021-04-24_Liverpool_1-1_Newcastle_x6R2Muj2.json: expected 2, found 3
# 2021-05-20_West_Brom_1-3_West_Ham_MXP00Gk4.json: expected 4, found 6
# 2020-10-17_Everton_2-2_Liverpool_hlr6Esaf.json: expected 4, found 5
# 2019-11-02_Levante_3-1_Barcelona_YL6qAivU.json: expected 4, found 5
# 2020-06-17_Barcelona_2-0_Leganes_hYV97ShC.json: expected 2, found 3
# 2020-07-06_Villarreal_1-4_Barcelona_vTOQivFm.json: expected 5, found 6
# 2020-06-18_Osasuna_0-5_Atl._Madrid_MmfXOTNn.json: expected 5, found 7
# 2023-09-03_Arsenal_3-1_Manchester_Utd_f7qWcC40.json: expected 4, found 5
# 2023-08-13_Newcastle_5-1_Aston_Villa_WtSNtKT8.json: expected 6, found 8
# 2023-08-19_Wolves_1-4_Brighton_p8zpnF5l.json: expected 5, found 6
# 2023-11-05_Nottingham_2-0_Aston_Villa_IHt5fhGb.json: expected 2, found 3
# 2023-09-16_Manchester_Utd_1-3_Brighton_0IqQFpQo.json: expected 4, found 5
# 2023-11-13_Chelsea_4-4_Manchester_City_UVvS9XFo.json: expected 8, found 9
# 2023-12-07_Manchester_Utd_2-1_Chelsea_WdSBQGdf.json: expected 3, found 4
# 2023-12-03_Liverpool_4-3_Fulham_KrhcLLKE.json: expected 7, found 8
# 2023-08-13_Chelsea_1-1_Liverpool_v7VVvbbL.json: expected 2, found 4
# 2023-09-30_Aston_Villa_6-1_Brighton_E3fbIwnp.json: expected 7, found 10
# 2018-04-01_Everton_1-3_Manchester_City_WYJEtalo.json: expected 4, found 5
# 2021-11-24_Dyn._Kyiv_1-2_Bayern_Munich_vszUxQB0.json: expected 3, found 4
# 2022-04-07_Villarreal_1-0_Bayern_Munich_WlUlHYSq.json: expected 1, found 2
# 2021-08-18_Salzburg_2-1_Brondby_t6pUdtpG.json: expected 3, found 5
# 2022-03-10_Manchester_City_0-0_Sporting_CP_0IkaEOM8.json: expected 0, found 2
# 2021-11-03_Atalanta_2-2_Manchester_Utd_YcGitHvE.json: expected 4, found 6
# 2021-09-29_RB_Leipzig_1-2_Club_Brugge_KV_lvIMrerM.json: expected 3, found 5
# 2021-09-15_Lille_0-0_Wolfsburg_QeeWYYWm.json: expected 0, found 1
# 2021-11-25_Liverpool_2-0_FC_Porto_SvnD3jyn.json: expected 2, found 3
# 2022-04-13_Real_Madrid_2-3_Chelsea_xn5lxz59.json: expected 5, found 6
# 2021-12-09_Zenit_3-3_Chelsea_tA8WjDit.json: expected 6, found 8
# 2021-08-19_Young_Boys_3-2_Ferencvaros_IqiELwwU.json: expected 5, found 7
# 2021-12-08_RB_Leipzig_2-1_Manchester_City_nPzQsFcS.json: expected 3, found 4
# 2022-04-14_Liverpool_3-3_Benfica_tKBuvdzc.json: expected 6, found 7
# 2021-11-04_Manchester_City_4-1_Club_Brugge_KV_fHIIqyTF.json: expected 5, found 6
# 2021-11-04_Liverpool_2-0_Atl._Madrid_ITvQ0lL4.json: expected 2, found 5
# 2021-10-21_Manchester_Utd_3-2_Atalanta_OSY0JgX0.json: expected 5, found 6
# 2021-11-24_Young_Boys_3-3_Atalanta_ClFeuyfK.json: expected 6, found 8
# 2022-02-16_Sporting_CP_0-5_Manchester_City_MRjeF472.json: expected 5, found 6
# 2021-08-26_Shakhtar_Donetsk_2-2_Monaco_hOMBiV3E.json: expected 4, found 5
# 2023-10-24_Fiorentina_0-2_Empoli_2auvolyE.json: expected 2, found 3
# 2023-10-29_Cagliari_4-3_Frosinone_MPwSZNSC.json: expected 7, found 8
# 2023-09-17_Genoa_2-2_Napoli_bitp6XjI.json: expected 4, found 5
# 2023-09-03_Napoli_1-2_Lazio_vNZpcx8m.json: expected 3, found 5
# 2023-09-16_Juventus_3-1_Lazio_4UKAiYyP.json: expected 4, found 5
# 2023-08-21_AS_Roma_2-2_Salernitana_lbAYWufr.json: expected 4, found 5
# 2021-02-14_Real_Madrid_2-0_Valencia_Isnv0Ixj.json: expected 2, found 3
# 2021-05-17_Atl._Madrid_2-1_Osasuna_0IN8buLR.json: expected 3, found 5
# 2021-03-06_Elche_2-1_Sevilla_WbLSbZdK.json: expected 3, found 4
# 2020-11-09_Valencia_4-1_Real_Madrid_YuiypxCB.json: expected 5, found 7
# 2020-12-30_Barcelona_1-1_Eibar_pCffQaY4.json: expected 2, found 3
# 2021-05-17_Ath_Bilbao_0-1_Real_Madrid_IgY3aL5L.json: expected 1, found 2
# 2021-03-01_Villarreal_0-2_Atl._Madrid_AViondDE.json: expected 2, found 3
# 2020-11-22_Atl._Madrid_1-0_Barcelona_jww7cetB.json: expected 1, found 2
# 2021-05-14_Granada_CF_1-4_Real_Madrid_4W9zb8UG.json: expected 5, found 6
# 2020-12-06_Cadiz_CF_2-1_Barcelona_vF1LTJM6.json: expected 3, found 4
# 2021-02-22_PSG_0-2_Monaco_ShH00Fdq.json: expected 2, found 3
# 2021-01-16_Montpellier_2-3_Monaco_foUrwRsL.json: expected 5, found 7
# 2020-03-01_Lecce_2-7_Atalanta_Uo3vjpqp.json: expected 9, found 10
# 2020-02-04_Sampdoria_2-4_Napoli_h4IXx19Q.json: expected 6, found 7
# 2019-08-25_Parma_0-1_Juventus_nPbjV5Df.json: expected 1, found 2
# 2019-08-26_Spal_2-3_Atalanta_INF1S3cD.json: expected 5, found 6
# 2019-10-06_AS_Roma_1-1_Cagliari_bks0kqIh.json: expected 2, found 3
# 2020-01-07_Napoli_1-3_Inter_CEG7lw7n.json: expected 4, found 5
# 2019-09-15_Brescia_3-4_Bologna_xlO2e2Ra.json: expected 7, found 9
# 2020-07-05_Lazio_0-3_AC_Milan_lWkoSbDb.json: expected 3, found 4
# 2019-09-15_Napoli_2-0_Sampdoria_tIb2G33P.json: expected 2, found 3
# 2020-02-09_Verona_2-1_Juventus_nRw7i0OJ.json: expected 3, found 4
# 2020-07-08_Lecce_2-1_Lazio_2ZFKtbSi.json: expected 3, found 5
# 2019-10-26_Lecce_1-1_Juventus_tE2Jn2J8.json: expected 2, found 3
# 2020-12-12_Dortmund_1-5_Stuttgart_QeXQnDxm.json: expected 6, found 8
# 2021-01-30_Bayern_Munich_4-1_Hoffenheim_vsrvSiJA.json: expected 5, found 6
# 2020-09-27_Hoffenheim_4-1_Bayern_Munich_lvpJu2UQ.json: expected 5, found 6
# 2021-04-03_Dortmund_1-2_Eintracht_Frankfurt_2eeE3Whq.json: expected 3, found 5
# 2021-03-20_Eintracht_Frankfurt_5-2_Union_Berlin_vFoPPM9o.json: expected 7, found 8
# 2020-10-05_Bayern_Munich_4-3_Hertha_Berlin_4A6lesUD.json: expected 7, found 8
# 2021-01-23_B._Monchengladbach_4-2_Dortmund_2eXaEYlB.json: expected 6, found 8
# 2021-04-04_RB_Leipzig_0-1_Bayern_Munich_tnfI2j8k.json: expected 1, found 2
# 2020-11-28_Stuttgart_1-3_Bayern_Munich_ld3qzzgs.json: expected 4, found 5
# 2020-10-31_FC_Koln_1-2_Bayern_Munich_A90PDntA.json: expected 3, found 4
# 2021-01-09_B._Monchengladbach_3-2_Bayern_Munich_235GoqF7.json: expected 5, found 6
# 2021-01-04_Bayern_Munich_5-2_Mainz_nReYY5V1.json: expected 7, found 8
# 2020-11-08_Dortmund_2-3_Bayern_Munich_0bgxBpQS.json: expected 5, found 7
# 2022-09-03_Tottenham_2-1_Fulham_UqQtNAn7.json: expected 3, found 5
# 2023-04-29_Crystal_Palace_4-3_West_Ham_6X1tgLP4.json: expected 7, found 8
# 2022-10-01_Arsenal_3-1_Tottenham_tGaDh2xh.json: expected 4, found 5
# 2022-09-02_Leicester_0-1_Manchester_Utd_xSMKHFAR.json: expected 1, found 2
# 2023-03-02_Arsenal_4-0_Everton_zsHWqYgK.json: expected 4, found 5
# 2023-04-15_Tottenham_2-3_Bournemouth_GpvdUGV6.json: expected 5, found 6
# 2023-05-13_Chelsea_2-2_Nottingham_KCu26VaL.json: expected 4, found 5
# 2023-04-27_Nottingham_3-1_Brighton_boNcr4Bn.json: expected 4, found 5
# 2023-02-16_Arsenal_1-3_Manchester_City_4hFAE4G8.json: expected 4, found 5
# 2023-01-23_Arsenal_3-2_Manchester_Utd_6HP3XCNt.json: expected 5, found 6
# 2023-02-18_Nottingham_1-1_Manchester_City_jqElXOpe.json: expected 2, found 3
# 2022-08-21_Bournemouth_0-3_Arsenal_Ctkp9TLu.json: expected 3, found 4
# 2022-08-27_Liverpool_9-0_Bournemouth_UsamHrKG.json: expected 9, found 11
# 2022-10-16_Liverpool_1-0_Manchester_City_WrqgEz5S.json: expected 1, found 2
# 2023-03-02_Liverpool_2-0_Wolves_rmjGyA10.json: expected 2, found 3
# 2023-02-11_Leicester_4-1_Tottenham_KtayQ7wS.json: expected 5, found 7
# 2023-01-14_Manchester_Utd_2-1_Manchester_City_8McwHiw0.json: expected 3, found 4
# 2023-04-05_Chelsea_0-0_Liverpool_trMpik1m.json: expected 0, found 1
# 2023-01-03_Brentford_3-1_Liverpool_OUgLAGGQ.json: expected 4, found 7
# 2023-04-28_Everton_1-4_Newcastle_EDoRmQmP.json: expected 5, found 7
# 2022-10-23_Tottenham_1-2_Newcastle_Ekms5iqC.json: expected 3, found 5
# 2023-05-21_Brighton_3-1_Southampton_0W0yLUEE.json: expected 4, found 5
# 2023-05-09_Nottingham_4-3_Southampton_Cjhemjgq.json: expected 7, found 8
# 2022-10-02_Manchester_City_6-3_Manchester_Utd_4fpwmb6T.json: expected 9, found 11
# 2022-08-14_Nottingham_1-0_West_Ham_EiAWk6LH.json: expected 1, found 3
# 2022-11-05_Manchester_City_2-1_Fulham_2mmgX9S4.json: expected 3, found 4
# 2022-08-23_Manchester_Utd_2-1_Liverpool_xlzA3PkH.json: expected 3, found 4
# 2023-05-09_Brighton_1-5_Everton_CSDCeEo3.json: expected 6, found 7
# 2022-09-01_Arsenal_2-1_Aston_Villa_nwU7KHQ8.json: expected 3, found 4
# 2022-09-04_Manchester_Utd_3-1_Arsenal_04xUPC2l.json: expected 4, found 5
# 2022-09-03_Chelsea_2-1_West_Ham_GW0cVYvR.json: expected 3, found 4
# 2023-03-11_Bournemouth_1-0_Liverpool_KxPM2Gzt.json: expected 1, found 2
# 2023-04-01_Manchester_City_4-1_Liverpool_WKdBMSXS.json: expected 5, found 6
# 2022-09-04_Brighton_5-2_Leicester_2TdgWEPK.json: expected 7, found 8
# 2022-10-01_Liverpool_3-3_Brighton_Q3oZmviN.json: expected 6, found 7
# 2023-04-29_Brighton_6-0_Wolves_O8Cyf1Ab.json: expected 6, found 7
# 2022-09-03_Everton_0-0_Liverpool_MDwQQhmr.json: expected 0, found 1
# 2022-08-07_Manchester_Utd_1-2_Brighton_040734YJ.json: expected 3, found 4
# 2023-10-08_Bayern_Munich_3-0_Freiburg_pSMShkRB.json: expected 3, found 4
# 2023-08-27_Bayern_Munich_3-1_Augsburg_f3e2PS0c.json: expected 4, found 5
# 2023-08-27_B._Monchengladbach_0-3_Bayer_Leverkusen_8Q1ILp0M.json: expected 3, found 4
# 2023-10-22_Mainz_1-3_Bayern_Munich_v52xaQmo.json: expected 4, found 5
# 2023-10-29_Eintracht_Frankfurt_3-3_Dortmund_8raD0wPk.json: expected 6, found 7
# 2023-11-11_Bayern_Munich_4-2_Heidenheim_2PphIQBK.json: expected 6, found 7
# 2023-08-26_RB_Leipzig_5-1_Stuttgart_lQf6OnG3.json: expected 6, found 7
# 2023-09-23_Bayern_Munich_7-0_Bochum_IwOCRCSC.json: expected 7, found 8
# 2019-04-28_Manchester_Utd_1-1_Chelsea_8SG7bP5C.json: expected 2, found 3
# 2018-11-25_Tottenham_3-1_Chelsea_EgD9VK0i.json: expected 4, found 5
# 2018-09-01_Leicester_1-2_Liverpool_fD0HGcZO.json: expected 3, found 4
# 2019-03-10_Chelsea_1-1_Wolves_beQqClZI.json: expected 2, found 3
# 2019-02-02_Chelsea_5-0_Huddersfield_0pC7YMTa.json: expected 5, found 6
# 2018-09-23_West_Ham_0-0_Chelsea_pK6po6ao.json: expected 0, found 1
# 2019-01-31_Bournemouth_4-0_Chelsea_0QqMMPUm.json: expected 4, found 5
# 2019-03-30_Fulham_0-2_Manchester_City_YmVFq2fi.json: expected 2, found 3
# 2022-01-15_FC_Koln_0-4_Bayern_Munich_rapxjeDp.json: expected 4, found 5
# 2021-11-20_B._Monchengladbach_4-0_Greuther_Furth_8MwJ3Kti.json: expected 4, found 5
# 2021-12-06_B._Monchengladbach_0-6_Freiburg_lG5l5XHe.json: expected 6, found 8
# 2022-04-24_Bayern_Munich_3-1_Dortmund_fiuP8trU.json: expected 4, found 5
# 2021-09-18_Bayern_Munich_7-0_Bochum_YXbWIyU4.json: expected 7, found 8
# 2022-02-06_Bayern_Munich_3-2_RB_Leipzig_KbEJ2Ydj.json: expected 5, found 6
# 2022-01-24_Hertha_Berlin_1-4_Bayern_Munich_6iYr9zKM.json: expected 5, found 7
# 2022-04-17_Arminia_Bielefeld_0-3_Bayern_Munich_CSkK9MSN.json: expected 3, found 4
# 2022-02-19_Augsburg_1-2_Freiburg_n7qWUBct.json: expected 3, found 4
# 2023-04-23_Lens_3-0_Monaco_W4v8BSwa.json: expected 3, found 4
# 2023-04-09_Nantes_2-2_Monaco_Q3eNclh2.json: expected 4, found 5
# 2022-08-28_Nantes_3-1_Toulouse_A9EMvoAj.json: expected 4, found 5
# 2023-04-02_Monaco_4-3_Strasbourg_YZ1umXwp.json: expected 7, found 8
# 2022-08-14_PSG_5-2_Montpellier_bkiexhlh.json: expected 7, found 8
# 2022-09-04_Clermont_2-0_Toulouse_fwvqhep7.json: expected 2, found 3
# 2023-02-26_Reims_3-0_Toulouse_U1T0Tosf.json: expected 3, found 4
# 2022-10-16_Toulouse_3-2_Angers_KzMPtmbR.json: expected 5, found 6
# 2018-03-01_Atl._Madrid_4-0_Leganes_WCMR1KPk.json: expected 4, found 3
# 2019-03-18_PSG_3-1_Marseille_fwSvBsj7.json: expected 4, found 6
# 2019-01-14_Marseille_1-1_Monaco_UJjJ4QAp.json: expected 2, found 3
# 2019-04-17_Juventus_1-2_Ajax_WhQHNA8E.json: expected 3, found 4
# 2019-04-18_Manchester_City_4-3_Tottenham_xjTPLlwR.json: expected 7, found 9
# 2018-12-12_Crvena_zvezda_1-4_PSG_QysxJXeP.json: expected 5, found 6
# 2019-05-01_Tottenham_0-1_Ajax_CK3ne74R.json: expected 1, found 2
# 2018-11-29_Lokomotiv_Moscow_2-0_Galatasaray_ATKKA935.json: expected 2, found 3
# 2019-02-13_AS_Roma_2-1_FC_Porto_v7ZspG8K.json: expected 3, found 4
# 2018-10-04_Lokomotiv_Moscow_0-1_Schalke_dQGGBkla.json: expected 1, found 2
# 2019-03-13_Juventus_3-0_Atl._Madrid_W4EMxY0f.json: expected 3, found 4
# 2019-02-21_Schalke_2-3_Manchester_City_bifqPEWf.json: expected 5, found 6
# 2019-04-18_FC_Porto_1-4_Liverpool_QFPLMUNK.json: expected 5, found 6
# 2019-03-07_FC_Porto_3-1_AS_Roma_KvQxZk0J.json: expected 4, found 5
# 2019-10-24_Ajax_0-1_Chelsea_hnoboAl1.json: expected 1, found 2
# 2019-10-23_Juventus_2-1_Lokomotiv_Moscow_reYzH7wg.json: expected 3, found 4
# 2020-08-16_Manchester_City_1-3_Lyon_KK30KFiJ.json: expected 4, found 6
# 2019-10-02_Juventus_3-0_Bayer_Leverkusen_xr3zJT8t.json: expected 3, found 4
# 2020-08-09_Bayern_Munich_4-1_Chelsea_Qaw6Odk7.json: expected 5, found 6
# 2019-10-24_Inter_2-0_Dortmund_KIMzryr9.json: expected 2, found 3
# 2019-08-14_FC_Copenhagen_1-2_Crvena_zvezda_YsUm9yEM.json: expected 3, found 15
# 2019-11-27_Manchester_City_1-1_Shakhtar_Donetsk_jPmQoPsi.json: expected 2, found 3
# 2019-10-24_Salzburg_2-3_Napoli_KbfkWwqc.json: expected 5, found 6
# 2019-11-28_Liverpool_1-1_Napoli_pOf6Wnwt.json: expected 2, found 3
# 2019-08-29_Ajax_2-0_APOEL_KMdvNjmo.json: expected 2, found 4
# 2019-10-24_Benfica_2-1_Lyon_tj6JZCkk.json: expected 3, found 4
# 2019-08-14_Celtic_3-4_CFR_Cluj_U7b4wcJG.json: expected 7, found 8
# 2019-11-06_Liverpool_2-1_Genk_UBdITpNb.json: expected 3, found 4
# 2019-09-19_PSG_3-0_Real_Madrid_IyJBS1sT.json: expected 3, found 4
# 2020-02-20_Atalanta_4-1_Valencia_Qaayvxkf.json: expected 5, found 6
# 2019-11-06_Lyon_3-1_Benfica_lE2FgYtL.json: expected 4, found 5
# 2019-11-06_Chelsea_4-4_Ajax_bevos1dM.json: expected 8, found 9
# 2023-09-24_Real_Sociedad_4-3_Getafe_2uq7EflH.json: expected 7, found 8
# 2023-08-27_Sevilla_1-2_Girona_zDm46KYr.json: expected 3, found 4
# 2023-08-27_Villarreal_3-4_Barcelona_Y31xB0QR.json: expected 7, found 8
# 2023-10-22_Sevilla_1-1_Real_Madrid_EgP7mLpf.json: expected 2, found 3
# 2017-09-14_Real_Madrid_3-0_APOEL_bJWrDir5.json: expected 3, found 4
# 2022-02-12_PSG_1-0_Rennes_Q77VY7o8.json: expected 1, found 2
# 2022-04-18_PSG_2-1_Marseille_hCjLLF8C.json: expected 3, found 5
# 2021-11-28_St_Etienne_1-3_PSG_dI4K37Tp.json: expected 4, found 6
# 2021-08-08_Metz_3-3_Lille_EaxuxyQK.json: expected 6, found 7
# 2021-10-25_Marseille_0-0_PSG_EFETfITF.json: expected 0, found 2
# 2019-05-18_Bayern_Munich_5-1_Eintracht_Frankfurt_4SiTZsnr.json: expected 6, found 7
# 2019-04-06_Bayer_Leverkusen_2-4_RB_Leipzig_QwIZ6Xfs.json: expected 6, found 7
# 2019-02-02_Bayer_Leverkusen_3-1_Bayern_Munich_j36dF1n8.json: expected 4, found 5
# 2019-05-28_WinnerUnion_Berlin_0-0_Stuttgart_CEbZx3yN.json: expected 0, found 1
# 2019-05-18_B._Monchengladbach_0-2_Dortmund_jqjyYLGf.json: expected 2, found 3
# 2019-05-11_RB_Leipzig_0-0_Bayern_Munich_dMU1JM11.json: expected 0, found 1
# 2019-02-25_Dortmund_3-2_Bayer_Leverkusen_SzbAIRbH.json: expected 5, found 6
# 2019-09-24_Wolfsburg_1-1_Hoffenheim_ny58xZtT.json: expected 2, found 3
# 2019-11-10_Bayern_Munich_4-0_Dortmund_Ghx3Jmyp.json: expected 4, found 6
# 2019-11-23_Dusseldorf_0-4_Bayern_Munich_lbtntBrc.json: expected 4, found 5
# 2020-06-14_Bayern_Munich_2-1_B._Monchengladbach_fiJPx6Co.json: expected 3, found 4
# 2020-01-18_Augsburg_3-5_Dortmund_86mXbyCj.json: expected 8, found 9
# 2020-05-24_Bayern_Munich_5-2_Eintracht_Frankfurt_G4fz1w0R.json: expected 7, found 8
# 2020-05-24_Mainz_0-5_RB_Leipzig_82ZEgeh1.json: expected 5, found 6
# 2020-12-03_Juventus_3-0_Dyn._Kyiv_lUSBmUfk.json: expected 3, found 4
# 2020-10-22_Inter_2-2_B._Monchengladbach_8GpobxFO.json: expected 4, found 5
# 2020-11-26_Bayern_Munich_3-1_Salzburg_EirzcjId.json: expected 4, found 5
# 2020-10-21_Lazio_3-1_Dortmund_lt9Yf638.json: expected 4, found 5
# 2020-11-25_PSG_1-0_RB_Leipzig_t0Pm01ul.json: expected 1, found 2
# 2021-03-10_Dortmund_2-2_Sevilla_AqDh7GJS.json: expected 4, found 5
# 2021-03-10_Juventus_3-2_FC_Porto_EHJq9xkG.json: expected 5, found 6
# 2020-12-02_Lokomotiv_Moscow_1-3_Salzburg_INa1bo97.json: expected 4, found 5
# 2020-09-16_Omonia_2-1_Crvena_zvezda_8tYL1jr4.json: expected 3, found 8
# 2020-10-22_Olympiacos_Piraeus_1-0_Marseille_4hHQVbUu.json: expected 1, found 2
# 2021-02-24_Atl._Madrid_0-1_Chelsea_ChaK2zSq.json: expected 1, found 2
# 2020-12-09_RB_Leipzig_3-2_Manchester_Utd_lMCfJtnQ.json: expected 5, found 6
# 2020-09-24_Gent_1-2_Dyn._Kyiv_YPh1XQl2.json: expected 3, found 4
# 2020-12-02_B._Monchengladbach_2-3_Inter_MJYSMLiP.json: expected 5, found 7
# 2020-10-29_Manchester_Utd_5-0_RB_Leipzig_MFK8ewfJ.json: expected 5, found 6
# 2022-08-13_Osasuna_2-1_Sevilla_4A6lVJSe.json: expected 3, found 4
# 2023-06-05_Betis_1-1_Valencia_lx5qBKi8.json: expected 2, found 3
# 2023-01-30_Celta_Vigo_1-0_Ath_Bilbao_zoPaagIF.json: expected 1, found 2
# 2022-10-30_Valencia_0-1_Barcelona_bun53pcS.json: expected 1, found 2
# 2023-02-04_Elche_3-1_Villarreal_xC6Bf4Wm.json: expected 4, found 5
# 2023-01-29_Valladolid_1-0_Valencia_I7Zpvqn7.json: expected 1, found 2
# 2022-10-03_Girona_3-5_Real_Sociedad_8Gb9KrXQ.json: expected 8, found 10
# 2022-10-29_Cadiz_CF_3-2_Atl._Madrid_0fT14QsM.json: expected 5, found 6

# %%
len(result)
# Out:
# 427

# %%
average_more_goals = sum(
    [abs(match['actual_goals']-match['expected_goals']) for match in result])/len(result)
average_more_goals
# Out:
# 1.215456674473068

# %%
special_matches = [
    match for match in result if match['actual_goals'] < match['expected_goals']]
special_matches
# Out:
# [{'file': '2019-04-30_Atalanta_2-0_Udinese_6w99xiq5.json',
#   'expected_goals': 2,
#   'actual_goals': 1},
#  {'file': '2020-09-20_Verona_3-0_AS_Roma_htMuKMqK.json',
#   'expected_goals': 3,
#   'actual_goals': 0},
#  {'file': '2022-10-06_Sevilla_1-4_Dortmund_YmXZ9lSh.json',
#   'expected_goals': 5,
#   'actual_goals': 4},
#  {'file': '2018-03-01_Atl._Madrid_4-0_Leganes_WCMR1KPk.json',
#   'expected_goals': 4,
#   'actual_goals': 3}]

# %%
# 6768是从比分上统计的ground truth进球数
6768 / (soccerreplay_1988_events['goal'])
# Out:
# 0.9304371734946384

# %% [markdown]
# #### 统计换人事件

# %%
import json
import os
from datetime import datetime


def calculate_average_substitutions(base_path, season_threshold):
    early_season_substitutions = []
    late_season_substitutions = []

    for root, dirs, files in os.walk(base_path):
        for file in files:
            if file.endswith('.json'):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    data = json.load(f)

                # 修正日期提取逻辑，从match_info.timestamp中获取日期
                match_date_str = data['match_info'].get(
                    'timestamp', '').split()[0]
                if not match_date_str:
                    continue

                try:
                    match_date = datetime.strptime(match_date_str, '%Y-%m-%d')
                except ValueError:
                    print(f"日期解析失败: {file}")
                    continue

                # 赛季计算逻辑保持不变
                season = f"{match_date.year}-{match_date.year + 1}" if match_date.month >= 8 else f"{match_date.year - 1}-{match_date.year}"

                # 统计换人次数（修正comments的获取方式）
                comments = data.get('comments', [])
                substitution_count = sum(1 for comment in comments if comment.get(
                    'comments_type', '').lower() == 'substitution')

                # 调试输出（可选）
                # print(f"{file}: {substitution_count}次换人，赛季{season}")

                # 分组统计
                if season < season_threshold:
                    early_season_substitutions.append(substitution_count)
                else:
                    late_season_substitutions.append(substitution_count)

    # 计算平均值（处理空列表情况）
    early_avg = sum(early_season_substitutions) / \
        len(early_season_substitutions) if early_season_substitutions else 0
    late_avg = sum(late_season_substitutions) / \
        len(late_season_substitutions) if late_season_substitutions else 0

    return early_avg, late_avg


# 修改路径为实际路径（注意路径分隔符）
base_path = '../SoccerReplay-1988/SoccerReplay-1988'  # 根据实际文件结构调整路径
season_threshold = '2019-2020'

# 调用函数并打印结果
early_avg, late_avg = calculate_average_substitutions(
    base_path, season_threshold)
print(f"早于2019-2020赛季的平均换人数量: {early_avg:.2f}")
print(f"晚于2019-2020赛季的平均换人数量: {late_avg:.2f}")
# Out:
# 早于2019-2020赛季的平均换人数量: 5.69
# 晚于2019-2020赛季的平均换人数量: 7.79
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。

# %% [markdown]
# ## 根据选定事件收集SoccerReplay-1988

# %%
import os
import json


def filter_comments_by_type(input_dir, output_dir, target_types):
    """
    过滤SoccerReplay-1988数据集中的注释事件，仅保留指定类型
    
    Args:
        input_dir (str): 原始数据集根目录路径
        output_dir (str): 过滤后数据保存目录
        target_types (list): 需要保留的comments_type列表
    """
    # 创建输出目录（如果不存在）
    os.makedirs(output_dir, exist_ok=True)

    for root, _, files in os.walk(input_dir):
        for file in files:
            if file.endswith('.json'):
                input_path = os.path.join(root, file)
                rel_path = os.path.relpath(root, input_dir)
                output_subdir = os.path.join(output_dir, rel_path)
                os.makedirs(output_subdir, exist_ok=True)
                output_path = os.path.join(output_subdir, file)

                try:
                    with open(input_path, 'r', encoding='utf-8') as f:
                        data = json.load(f)

                    # 过滤comments数组
                    filtered_comments = [
                        comment for comment in data.get('comments', [])
                        if comment.get('comments_type') in target_types
                    ]

                    data['comments'] = filtered_comments  # 更新数据

                    # 保存处理后的文件
                    with open(output_path, 'w', encoding='utf-8') as f:
                        json.dump(data, f, indent=2, ensure_ascii=False)

                    print(f"Processed: {file}")

                except json.JSONDecodeError as e:
                    print(f"JSON解析错误: {input_path}, 错误: {str(e)}")
                except Exception as e:
                    print(f"处理文件失败: {input_path}, 错误: {str(e)}")


if __name__ == "__main__":
    # 需要保留的事件类型列表
    valid_types = [
        'corner', 'substitution', 'yellow card',
        'second yellow card', 'red card', 'goal',
        'penalty'
    ]

    # 设置输入输出路径
    input_directory = "../SoccerReplay-1988/SoccerReplay-1988"
    output_directory = "../Long-Video-QA/Data"

    # 执行过滤操作
    filter_comments_by_type(input_directory, output_directory, valid_types)

# %%
import os 
import json

# 遍历指定目录下的所有JSON文件，为每个注释添加索引，并直接写回源文件。
def add_comment_index(directory):
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.json'):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    data = json.load(f)

                # 为每个注释添加索引
                for i, comment in enumerate(data.get('comments', [])):
                    comment['index'] = i + 1

                # 将修改后的数据写回原文件
                with open(file_path, 'w', encoding='utf-8') as f:
                    json.dump(data, f, indent=2, ensure_ascii=False)
                print(f"已处理文件: {file_path}")


input_directory = "../Long-Video-QA/Data" 
add_comment_index(input_directory)

# %%
from openai import OpenAI


def workflow(input_text, Instruction, follow_up_prompt=None, api_key="sk-FOvSp53sdWa96yE71d74F52a4d074d7f9128E7Bb4f113cE7"):
    client = OpenAI(api_key=api_key,
                    base_url="https://az.gptplus5.com/v1", timeout=2400.0)
    completion = client.chat.completions.create(
        model="chatgpt-4o-latest",
        messages=[
            {"role": "system", "content": Instruction},
            {"role": "user", "content": input_text}
        ],
        timeout=2400.0,
        stream=False
    )

    first_round_reply = completion.choices[0].message.content

    return first_round_reply


workflow("What is the score of the match?",
         "You are a soccer expert. Please answer the question as accurately as possible.")
# Out:
# "Unfortunately, I don't have real-time access to live match scores or events. To check the current score of a soccer match, you can visit a sports website, use a mobile app like ESPN or FlashScore, or check with broadcasters covering the game. Let me know if you need help finding information on a specific match!"

# %%
import os
import json

with open("./2017-08-12_Watford_3-3_Liverpool_AaZvBO5T_goals.json", 'r', encoding='utf-8') as f:
    data = json.load(f)
len(data)
# Out:
# 15

# %% [markdown]
# ## 生成QA对

# %% [markdown]
# #### 尝试JSON Mode

# %%
import json
from openai import OpenAI


QA_SCHEMA = {
    "name": "generate_qa_pairs",
    "description": "Returns an array of QA pair objects in the specified format.",
    "parameters": {
        "type": "array",
        "items": {
            "type": "object",
            "properties": {
                "question":         {"type": "string"},
                "choices": {
                    "type": "array",
                    "items": {"type": "string"},
                    "minItems": 2,
                    "maxItems": 4
                },
                "answer":           {"type": "string", "enum": ["A", "B", "C", "D"]},
                "type":             {"type": "string", "enum": ["past", "full", "future"]},
                "question_level":   {"type": "string", "enum": ["match_level", "team_level", "player_level"]},
                "related_event": {
                    "type": "array",
                    "items": {"type": "integer"}
                },
                "current_event_index": {
                    "anyOf": [
                        {"type": "integer"},
                        {"type": "null"}
                    ]
                },
                "index":            {"type": "integer"}
            },
            "required": ["question", "choices", "answer", "type", "question_level", "related_event", "current_event_index", "index"]
        }
    }
}


def workflow(input_text, Instruction, follow_up_prompt=None, api_key="sk-FOvSp53sdWa96yE71d74F52a4d074d7f9128E7Bb4f113cE7"):
    client = OpenAI(api_key=api_key,
                    base_url="https://az.gptplus5.com/v1", timeout=2400.0)

    completion = client.chat.completions.create(
        # model="deepseek-chat",
        model="chatgpt-4o-latest",
        messages=[
            {"role": "system", "content": Instruction},
            {"role": "user",   "content": input_text}
        ],
        functions=[QA_SCHEMA],
        function_call={"name": "generate_qa_pairs"},
        timeout=2400.0,
        stream=False
    )
    
    # 这里直接拿到已经是 JSON 格式的字符串
    args = completion.choices[0].message.function_call.arguments
    return json.loads(args)


def clean_json_block(text):
    if text.strip().startswith("```"):
        lines = text.strip().splitlines()
        return "\n".join(lines[1:-1])
    return text


def extract_goal_comments(json_file_path):
    with open(json_file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)

    comments_list = data.get("comments", [])
    result = []

    for comment in comments_list:
        if comment.get("comments_type") != "goal":
            continue

        half = comment.get("half")
        if half not in [1, 2]:
            continue

        timestamp = comment.get("time_stamp", "")
        if not timestamp:
            continue

        comments_text = comment.get("comments_text", "")
        if not comments_text:
            continue

        index = comment.get("index", -1)  # 获取index，如果不存在则默认为-1
        half_str = "1st half" if half == 1 else "2nd half"
        commentary_line = f"{half_str} - {timestamp} \"{comments_text}\" (Index: {index})"
        result.append(commentary_line)

    return "\n".join(result)


def generate_qa_pairs(json_path, save_path):
    goal_comments = extract_goal_comments(json_path)

    input_text = f"""Follow these requirements:

1. CONTEXT:
The provided text contains goal-related commentary from a football match. Use this to create three types of QA pairs across three different levels. 
When done, call the function `generate_qa_pairs` to return your JSON object with a 'qa_pairs' property containing the array of QA pairs.

2. QA TYPES AND EXAMPLES:
A. Past Video QA (At least 3 questions per level)
Match Level Examples:
  * "How many goals have been scored in the match so far?"
  * "What is the current score of the match?"
  * "How many minutes passed between the first and second goals?"

Team Level Examples:
  * "How many goals has Liverpool scored up to this point?"
  * "Which team scored the most recent goal?"
  * "Has Watford managed to take the lead yet?"

Player Level Examples:
  * "Who scored the opening goal of the match?"
  * "Has Roberto Firmino scored any goals so far?"
  * "Which player provided the assist for the last goal?"

B. Full Video QA (At least 3 questions per level)
Match Level Examples:
  * "How many total goals were scored in the match?"
  * "In which half were more goals scored?"
  * "What was the final score of the match?"

Team Level Examples:
  * "How many goals did Watford score in total?"
  * "Which team scored more goals in the second half?"
  * "Did both teams score in both halves?"

Player Level Examples:
  * "Who scored the most goals in the match?"
  * "Which players scored for Liverpool?"
  * "Did any player score multiple goals?"

C. Future Prediction QA (At least 3 questions per level, Can be asked during the middle of the match)
Match Level Examples:
  * "Will there be more goals in this match?"
  * "Will the match end in a draw?"
  * "How many more goals will be scored in this match?"
  * "Who will score the next goal?"

Team Level Examples:
  * "Which team is more likely to score next?"
  * "Will the trailing team manage to equalize?"
  * "Will either team keep a clean sheet in the remaining time?"

Player Level Examples:
  * "Will any substitute player score in the remaining time?"
  * "Will any player complete a hat-trick?"
  * "Which striker is most likely to score next?"

3. REQUIREMENTS:
- Generate at least 5 questions of each type
- Questions must require the provided goal data to answer
- Every question must be a multiple choice question with 2-4 choices
- Questions must cover all three levels:
  * match_level: Questions about overall match statistics or events
  * team_level: Questions about specific team's performance
  * player_level: Questions about individual player's actions
- related_event must be a list of indices referring to relevant goal events
- Vary question formats and complexity
- Include specific details from the commentary
- Ensure answers are clear, concise and accurate
- For prediction questions, use knowledge of all events to provide correct answers
- For 'past' and 'future' types, include the 'current_event_index' field
- For 'full' type, set 'current_event_index' to None

5. COMMENTARY:
{goal_comments}

Generate the QA pairs in the specified JSON format only."""

    instruction = "You are a football analyst tasked with creating diverse QA pairs from goal-related match commentary. Ensure that answers are generated by considering ALL events in the match."

    qa_pairs_response = workflow(
        input_text=input_text, Instruction=instruction)
    qa_pairs = qa_pairs_response.get("qa_pairs", [])

    # qa_pairs = clean_json_block(qa_pairs)

    return qa_pairs


if __name__ == "__main__":
    match_path = "../Long-Video-QA/Data/england_epl_2017-2018/2017-08-12_watford-fc-liverpool-fc/2017-08-12_Watford_3-3_Liverpool_AaZvBO5T.json"
    save_path = "./2017-08-12_Watford_3-3_Liverpool_AaZvBO5T_goals.json"
    qa_pairs = generate_qa_pairs(match_path, save_path)

# %% [markdown]
# ### 尝试使用deepseek

# %%
import json
from openai import OpenAI


def workflow(input_text, Instruction, follow_up_prompt=None, api_key="sk-3db847df235b46d894d71b425c57c0f0"):
    client = OpenAI(api_key=api_key,
                    base_url="https://api.deepseek.com", timeout=2400.0)
    completion = client.chat.completions.create(
        # model="chatgpt-4o-latest",
        model="deepseek-chat",
        messages=[
            {"role": "system", "content": Instruction},
            {"role": "user", "content": input_text}
        ],
        timeout=2400.0,
        stream=False
    )

    first_round_reply = completion.choices[0].message.content

    return first_round_reply


workflow("What is the score of the match?",
         "You are a soccer expert. Please answer the question as accurately as possible.")
# Out:
# "I currently don't have access to live match scores. You can check the latest scores on sports websites like **ESPN**, **BBC Sport**, **SofaScore**, or **FlashScore**.  \n\nLet me know if you'd like historical match results or analysis on a specific game!"

# %%
import json
from openai import OpenAI


def workflow(input_text, Instruction, follow_up_prompt=None, api_key="sk-FOvSp53sdWa96yE71d74F52a4d074d7f9128E7Bb4f113cE7"):
    client = OpenAI(api_key=api_key,
                    base_url="https://az.gptplus5.com/v1", timeout=2400.0)
    completion = client.chat.completions.create(
        # model="chatgpt-4o-latest",
        model="deepseek-chat",
        messages=[
            {"role": "system", "content": Instruction},
            {"role": "user", "content": input_text}
        ],
        timeout=2400.0,
        stream=False
    )

    first_round_reply = completion.choices[0].message.content

    return first_round_reply


def clean_json_block(text):
    if text.strip().startswith("```"):
        lines = text.strip().splitlines()
        return "\n".join(lines[1:-1])
    return text


def extract_goal_comments(json_file_path):
    with open(json_file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)

    comments_list = data.get("comments", [])
    result = []

    for comment in comments_list:
        if comment.get("comments_type") != "goal":
            continue

        half = comment.get("half")
        if half not in [1, 2]:
            continue

        timestamp = comment.get("time_stamp", "")
        if not timestamp:
            continue

        comments_text = comment.get("comments_text", "")
        if not comments_text:
            continue

        index = comment.get("index", -1)  # 获取index，如果不存在则默认为-1
        half_str = "1st half" if half == 1 else "2nd half"
        commentary_line = f"{half_str} - {timestamp} \"{comments_text}\" (Index: {index})"
        result.append(commentary_line)

    return "\n".join(result)


def generate_qa_pairs(json_path, save_path):
    goal_comments = extract_goal_comments(json_path)

    input_text = f"""Follow these requirements:

1. CONTEXT:
The provided text contains goal-related commentary from a football match. Use this to create three types of QA pairs across three different levels:

2. QA TYPES AND EXAMPLES:
A. Past Video QA (At least 3 questions per level)
Match Level Examples:
  * "How many goals have been scored in the match so far?"
  * "What is the current score of the match?"
  * "How many minutes passed between the first and second goals?"

Team Level Examples:
  * "How many goals has Liverpool scored up to this point?"
  * "Which team scored the most recent goal?"
  * "Has Watford managed to take the lead yet?"

Player Level Examples:
  * "Who scored the opening goal of the match?"
  * "Has Roberto Firmino scored any goals so far?"
  * "Which player provided the assist for the last goal?"

B. Full Video QA (At least 3 questions per level)
Match Level Examples:
  * "How many total goals were scored in the match?"
  * "In which half were more goals scored?"
  * "What was the final score of the match?"

Team Level Examples:
  * "How many goals did Watford score in total?"
  * "Which team scored more goals in the second half?"
  * "Did both teams score in both halves?"

Player Level Examples:
  * "Who scored the most goals in the match?"
  * "Which players scored for Liverpool?"
  * "Did any player score multiple goals?"

C. Future Prediction QA (At least 3 questions per level, Can be asked during the middle of the match)
Match Level Examples:
  * "Will there be more goals in this match?"
  * "Will the match end in a draw?"
  * "How many more goals will be scored in this match?"
  * "Who will score the next goal?"

Team Level Examples:
  * "Which team is more likely to score next?"
  * "Will the trailing team manage to equalize?"
  * "Will either team keep a clean sheet in the remaining time?"

Player Level Examples:
  * "Will any substitute player score in the remaining time?"
  * "Will any player complete a hat-trick?"
  * "Which striker is most likely to score next?"

3. RESPONSE FORMAT:
You MUST ONLY RETURN A JSON ARRAY of objects with this structure:
{{
    "question": "The question text",
    "choices": ["A. Choice A", "B. Choice B", "C. Choice C", "D. Choice D"],  # 2-4 choices
    "answer": "The correct choice letter (A/B/C/D)",
    "type": "past/full/future",
    "question_level": "match_level/team_level/player_level",
    "related_event": [0, 1, 2],  # List of related event indices in ascending order
    "current_event_index": 5,  # Index of the current event for 'past' and 'future' types, None for 'full'
    "index": 0  # The index of the question in the original commentary, starting from 0
}}
You MUST NOT include any other text or explanation.

4. REQUIREMENTS:
- Generate at least 5 questions of each type
- Questions must require the provided goal data to answer
- Every question must be a multiple choice question with 2-4 choices
- Questions must cover all three levels:
  * match_level: Questions about overall match statistics or events
  * team_level: Questions about specific team's performance
  * player_level: Questions about individual player's actions
- related_event must be a list of indices referring to relevant goal events
- Vary question formats and complexity
- Include specific details from the commentary
- Ensure answers are clear, concise and accurate
- For prediction questions, use knowledge of all events to provide correct answers
- For 'past' and 'future' types, include the 'current_event_index' field
- For 'full' type, set 'current_event_index' to None

5. COMMENTARY:
{goal_comments}

Generate the QA pairs in the specified JSON format only."""

    instruction = "You are a football analyst tasked with creating diverse QA pairs from goal-related match commentary. Ensure that answers are generated by considering ALL events in the match."

    qa_pairs = workflow(input_text=input_text,
                        Instruction=instruction)

    qa_pairs = clean_json_block(qa_pairs)

    return qa_pairs


if __name__ == "__main__":
    match_path = "../Long-Video-QA/Data/england_epl_2017-2018/2017-08-12_watford-fc-liverpool-fc/2017-08-12_Watford_3-3_Liverpool_AaZvBO5T.json"
    save_path = "./2017-08-12_Watford_3-3_Liverpool_AaZvBO5T_goals.txt"
    qa_pairs = generate_qa_pairs(match_path, save_path)

# %%
qa_pairs
# Out:
# '[\n    {\n        "question": "How many goals have been scored in the match so far?",\n        "choices": ["A. 1", "B. 2", "C. 3", "D. 4"],\n        "answer": "C",\n        "type": "past",\n        "question_level": "match_level",\n        "related_event": [1, 3, 4],\n        "current_event_index": 4,\n        "index": 0\n    },\n    {\n        "question": "What is the current score of the match?",\n        "choices": ["A. 1:0", "B. 1:1", "C. 2:1", "D. 2:2"],\n        "answer": "C",\n        "type": "past",\n        "question_level": "match_level",\n        "related_event": [1, 3, 4],\n        "current_event_index": 4,\n        "index": 1\n    },\n    {\n        "question": "How many minutes passed between the first and second goals?",\n        "choices": ["A. 7 minutes", "B. 20 minutes", "C. 28 minutes", "D. 31 minutes"],\n        "answer": "B",\n        "type": "past",\n        "question_level": "match_level",\n        "related_event": [1, 3],\n        "current_event_index": 3,\n        "index": 2\n    },\n    {\n        "question": "How many goals has Liverpool scored up to this point?",\n        "choices": ["A. 0", "B. 1", "C. 2", "D. 3"],\n        "answer": "B",\n        "type": "past",\n        "question_level": "team_level",\n        "related_event": [3],\n        "current_event_index": 4,\n        "index": 3\n    },\n    {\n        "question": "Which team scored the most recent goal?",\n        "choices": ["A. Liverpool", "B. Watford", "C. Neither", "D. Both"],\n        "answer": "B",\n        "type": "past",\n        "question_level": "team_level",\n        "related_event": [4],\n        "current_event_index": 4,\n        "index": 4\n    },\n    {\n        "question": "Who scored the opening goal of the match?",\n        "choices": ["A. Sadio Mane", "B. Stefano Okaka", "C. Abdoulaye Doucoure", "D. Roberto Firmino"],\n        "answer": "B",\n        "type": "past",\n        "question_level": "player_level",\n        "related_event": [1],\n        "current_event_index": 4,\n        "index": 5\n    },\n    {\n        "question": "How many total goals were scored in the match?",\n        "choices": ["A. 3", "B. 4", "C. 5", "D. 6"],\n        "answer": "D",\n        "type": "full",\n        "question_level": "match_level",\n        "related_event": [1, 3, 4, 10, 11, 21],\n        "current_event_index": null,\n        "index": 6\n    },\n    {\n        "question": "In which half were more goals scored?",\n        "choices": ["A. First half", "B. Second half", "C. Equal", "D. None"],\n        "answer": "B",\n        "type": "full",\n        "question_level": "match_level",\n        "related_event": [1, 3, 4, 10, 11, 21],\n        "current_event_index": null,\n        "index": 7\n    },\n    {\n        "question": "What was the final score of the match?",\n        "choices": ["A. 2:2", "B. 2:3", "C. 3:3", "D. 3:4"],\n        "answer": "C",\n        "type": "full",\n        "question_level": "match_level",\n        "related_event": [1, 3, 4, 10, 11, 21],\n        "current_event_index": null,\n        "index": 8\n    },\n    {\n        "question": "How many goals did Watford score in total?",\n        "choices": ["A. 1", "B. 2", "C. 3", "D. 4"],\n        "answer": "C",\n        "type": "full",\n        "question_level": "team_level",\n        "related_event": [1, 4, 21],\n        "current_event_index": null,\n        "index": 9\n    },\n    {\n        "question": "Which team scored more goals in the second half?",\n        "choices": ["A. Liverpool", "B. Watford", "C. Equal", "D. None"],\n        "answer": "A",\n        "type": "full",\n        "question_level": "team_level",\n        "related_event": [10, 11, 21],\n        "current_event_index": null,\n        "index": 10\n    },\n    {\n        "question": "Who scored the most goals in the match?",\n        "choices": ["A. Roberto Firmino", "B. Mohamed Salah", "C. Stefano Okaka", "D. Abdoulaye Doucoure"],\n        "answer": "A",\n        "type": "full",\n        "question_lev ...

# %%
import os
path = './Data/england_epl_2017-2018/2017-08-12_watford-fc-liverpool-fc/2017-08-12_Watford_3-3_Liverpool_AaZvBO5T.json'
os.listdir('./Tiny_QA/Subject_Data/2017-08-12_watford-fc-liverpool-fc')[0]
# Out:
# '2017-08-12_Watford_3-3_Liverpool_AaZvBO5T.json'
